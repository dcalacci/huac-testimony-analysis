# %% [markdown]
# # Generating the confusion matrix between LIWC and CoreNLP
#
# ## Setup

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_pickle('paper_03_2014/df.p')

# %%
df.head().T
# Out:
#                                                                                                      2   \
# is_interviewee                                                                                    False
# is_response                                                                                       False
# liwc_categories_by_sentence                           [{}, {u'Negate': 0.5}, {u'Pronoun': 0.125, u'F...
# liwc_categories_for_speechact                         {u'Pronoun': 0.0416666666667, u'Future': 0.041...
# liwc_sentiment_by_sentence                                                             [0.0, 0.0, -0.2]
# liwc_sentiment_for_speechact                                                                -0.06666667
# liwc_sentiment_towards_entities_with_anaphora                                                       NaN
# liwc_sentiment_towards_entities_without_anaphora                                         {u'JACK': 0.0}
# ...
